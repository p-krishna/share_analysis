# %%
import os
import requests
from time import sleep
import pandas as pd
from tqdm import tqdm

# %%
url = 'https://stock-symbol-lookup-api.onrender.com/COMPANY_NAME={name}'

# %%
profit_companies = [
    'St Bk of India', 'HDFC Bank', 'Reliance Industr', 'ICICI Bank', 'TCS', 'Life Insurance', 'O N G C', 'Tata Motors', 'Axis Bank', 'Infosys', 'Power Fin.Corpn.', 'NTPC', 'Bank of Baroda', 'Bharti Airtel', 'ITC', 'Kotak Mah. Bank', 'HCL Technologies', 'Punjab Natl.Bank', 'Canara Bank', 'Union Bank (I)', 'Bajaj Finance', 'REC Ltd', 'Maruti Suzuki', 'Hindalco Inds.', 'Larsen & Toubro', 'Adani Power', 'M & M', 'Vedanta', 'Sun Pharma.Inds.', 'Indian Bank', 'Adani Ports', 'GAIL (India)', 'Hind. Unilever', 'Indus Towers', 'Hindustan Zinc', 'Hind.Aeronautics', 'Bajaj Finserv', 'Bank of India', 'Shriram Finance', 'Bajaj Auto', 'General Insuranc', 'Bajaj Holdings', 'Oil India', 'IndusInd Bank', 'IDBI Bank', 'I R F C', 'NMDC', 'UltraTech Cem.', 'Interglobe Aviat', 'H P C L',
    'Dr Reddys Labs', 'Bank of Maha', 'LIC Housing Fin.', 'Bharat Electron', 'Cipla', 'Muthoot Finance', 'LTIMindtree', 'Zydus Lifesci.', 'Eicher Motors', 'Ambuja Cements', 'Hero Motocorp', 'Samvardh. Mothe.', 'Grasim Inds', 'Cholaman.Inv.&Fn', 'Federal Bank', 'Authum Invest', 'Natl. Aluminium', 'Tata Power Co.', 'Adani Enterp.', 'DLF', 'Aditya Birla Cap', 'Central Bank', 'Aurobindo Pharma', 'Motil.Oswal.Fin.', 'Titan Company', 'Nestle India', 'I O B', 'Lupin', 'Ashok Leyland', 'Mazagon Dock', 'Avenue Super.', 'NHPC Ltd', 'H U D C O', 'Varun Beverages', 'Oberoi Realty', 'L&T Finance Ltd', 'ICICI Lombard', 'Macrotech Devel.', 'Bandhan Bank', 'M & M Fin. Serv.', 'SBI Life Insuran', 'ACC', 'GE Shipping Co', 'HDFC AMC', 'Torrent Power', 'UCO Bank', 'Oracle Fin.Serv.', 'NLC India', 'Britannia Inds.', 'Yes Bank',
    'Alkem Lab', 'Embassy Off.REIT', 'J & K Bank', 'ICICI Securities', 'Chola Financial', 'Divis Lab.', 'SBI Cards', 'AU Small Finance', 'Bosch', 'Pidilite Inds.', 'TVS Motor Co.', 'Manappuram Fin.', 'Bajaj Housing', 'Cummins India', 'Mankind Pharma', 'IDFC First Bank', 'Karur Vysya Bank', 'A B B', 'Natco Pharma', 'Torrent Pharma.', 'Jindal Saw', 'Polycab India', 'PNB Housing', 'Balkrishna Inds', 'Dabur India', 'MRF', 'HDFC Life Insur.', 'P I Industries', 'Mphasis', 'Sundaram Finance', 'Jio Financial', 'Marico', 'Indian Hotels Co', 'Indian Renewable', 'Lloyds Metals', 'Indraprastha Gas', 'Trent', 'Godrej Propert.', 'United Spirits', 'Colgate-Palmoliv', 'Adani Green', 'Havells India', 'CESC', 'Apollo Tyres', 'Angel One', 'Guj.St.Petronet', 'Abbott India', 'Container Corpn.', 'Nippon Life Ind.', 'JSW Infrast',
    'Persistent Sys', 'Tata Consumer', 'Apollo Hospitals', 'L&T Technology', 'I R C T C', 'Gujarat Gas', 'Redington', 'Adani Wilmar', 'Suzlon Energy', 'Patanjali Foods', 'SRF', 'Escorts Kubota', 'Berger Paints', 'Bombay Burmah', 'Solar Industries', 'TVS Holdings', 'Tata Comm', 'City Union Bank', '360 ONE', 'IIFL Finance', 'Nava', 'Max Healthcare', 'Mahanagar Gas', 'Bharti Hexacom', 'Godfrey Phillips', 'Phoenix Mills', 'Five-Star Bus.Fi', 'Supreme Inds.', 'New India Assura', 'Schaeffler India', 'Bharat Forge', 'Amara Raja Ener.', 'Uno Minda', 'CG Power & Ind', 'BSE', 'Castrol India', 'SJVN', 'Altius Telecom', 'Aditya AMC', 'Nuvama Wealth', 'Shyam Metalics', 'Ajanta Pharma', 'Deepak Fertiliz.', 'Aadhar Hsg. Fin.', 'Glaxosmi. Pharma', 'Vardhman Textile', 'Pun. & Sind Bank', 'M R P L', 'NCC', 'K P R Mill Ltd',
    'Biocon', 'Cochin Shipyard', 'Tube Investments', 'Tata Elxsi', 'Godawari Power', 'Apar Inds.', 'UTI AMC', 'Endurance Tech.', 'Exide Inds.', 'Star Health Insu', 'Emami', 'Fortis Health.', 'Narayana Hrudaya', 'Swan Energy', 'Coforge', 'KPIT Technologi.', 'Jai Balaji Inds.', 'IRB Infra.Devl.', 'Ipca Labs.', 'P & G Hygiene', 'Voltas', 'Aptus Value Hou.', 'Gland Pharma', 'EIH', 'Deepak Nitrite', 'CRISIL', 'Sarda Energy', 'Page Industries', 'Adani Total Gas', 'Tejas Networks', 'Kalyan Jewellers', 'Zomato Ltd', 'Zensar Tech.', 'J B Chemicals &', 'Info Edg.(India)', 'KEI Industries', 'Welspun Living', 'Brigade Enterpr.', 'Dixon Technolog.', 'Cyient', 'APL Apollo Tubes', 'Motherson Wiring', 'J K Cements', 'Kansai Nerolac', 'Pfizer', 'Thermax', 'Emcure Pharma', 'BASF India', 'Sona BLW Precis.', 'Alembic Pharma',
    'L T Foods', 'Birlasoft Ltd', 'NBCC', 'Bharat Dynamics', 'AAVAS Financiers', 'Firstsour.Solu.', '3M India', 'C D S L', 'Sundram Fasten.', 'Blue Star', 'DCM Shriram', 'Finolex Cables', 'SKF India', 'Honeywell Auto', 'Mindspace Busine', 'Astral', 'Crompton Gr. Con', 'eClerx Services', 'Caplin Point Lab', 'Nexus Select', 'Himadri Special', 'Kalpataru Proj.', 'Sumitomo Chemi.', 'Multi Comm. Exc.', 'CEAT', 'Global Health', 'Force Motors', 'GE Vernova T&D', 'Avanti Feeds', 'Gillette India', 'Indiamart Inter.', 'Gujarat Fluoroch', 'K E C Intl.', 'BLS Internat.', 'Carborundum Uni.', 'PCBL Chemical', 'United Breweries', 'Kirl. Brothers', 'Cams Services', 'Akzo Nobel', 'Sonata Software', 'Dr Lal Pathlabs', 'Atul', 'Supreme Petroch.', 'Usha Martin', 'Metro Brands', 'Fine Organic', 'Vedant Fashions', 'Hindustan Copper', 'Timken India',
    'Indian Energy Ex', 'Garden Reach Sh.', 'Vinati Organics', 'Action Const.Eq.', 'Shakti Pumps', 'Anant Raj', 'Capri Global', 'Indegene', 'Ramkrishna Forg.', 'Jupiter Wagons', 'IndiGrid Trust', 'Jyothy Labs', 'Grindwell Norton', 'Affle India', 'HFCL', 'Aarti Industries', 'Go Digit General', 'Bata India', 'Kajaria Ceramics', 'Krishna Institu.', 'Cello World', 'Triveni Turbine', 'Whirlpool India', 'HBL Engineering', 'ERIS Lifescience', 'Concord Biotech', 'Asahi India Glas', 'Elgi Equipments', 'KFin Technolog.', 'Techno Elec.Engg', 'Zydus Wellness', 'Poly Medicure', 'Hitachi Energy', 'Radico Khaitan', 'Inox Wind', 'Jyoti CNC Auto.', 'Trident', 'Newgen Software', 'Titagarh Rail', 'Hatsun Agro', 'Gravita India', 'Anand Rathi Wea.', 'Bikaji Foods', 'Blue Dart Expres', 'Minda Corp', 'Navin Fluo.Intl.', 'Ingersoll-Rand', 'V-Guard Industri', 'Clean Science', 'R R Kabel',
    'Kaynes Tech', 'National High', 'KSB', 'Rainbow Child.', 'Blue Jet Health', 'Jubilant Food.', 'Amber Enterp.', 'Century Plyboard', 'TBO Tek', 'Happiest Minds', 'Zen Technologies', 'PG Electroplast', 'PB Fintech.', 'Schneider Elect.`', 'Laurus Labs', 'Doms Industries', 'Craftsman Auto', 'JBM Auto', 'Lemon Tree Hotel', 'JSW Holdings', 'Poonawalla Fin', 'T R I L', 'Safari Inds.', 'Vijaya Diagnost.', 'Ami Organics', 'Aether Industri.', 'Chalet Hotels', 'Inox Wind Energy', 'Brookfield India', 'SignatureGlobal', 'Sobha', 'FSN E-Commerce', 'PTC Industries', 'Sapphire Foods', 'Westlife Food'
]

# %%
len(profit_companies), len(set(profit_companies))

# %%
list_results = []

for comp in tqdm(profit_companies) :
    url_filled = url.format(name=comp)
    response = requests.get(url_filled)
    if (response.status_code == 200) | (response.status_code == 404) :
        response_json = response.json()
        response_json['name'] = comp
        list_results.append(response_json)
        sleep(3)
    else :
        print('request failed :')
        print(response.json())

# %%
df_results = pd.DataFrame(list_results)
df_results

# %%
df_count = pd.DataFrame(df_results['stock_symbol'].value_counts() > 1).reset_index()
df_unique = df_count.loc[df_count['count'] == False, ['stock_symbol']]
df_ticker = df_unique.merge(df_results, on=['stock_symbol']).sort_values('stock_symbol').drop(columns=['detail'])
df_ticker

# %%
df_nifty500 = pd.read_csv('./data/ind_nifty500list.csv')
df_final = df_nifty500.merge(df_ticker, left_on='Symbol', right_on='stock_symbol').sort_values('stock_symbol')
df_final

# %%
df_final.to_csv('./data/ticker/final.csv', index=None)

# %%
df_final = pd.read_csv('./data/ticker/final.csv')
set(profit_companies) - set(df_final['name'])
# Out:
# {'360 ONE',
#  '3M India',
#  'A B B',
#  'AAVAS Financiers',
#  'APL Apollo Tubes',
#  'AU Small Finance',
#  'Aadhar Hsg. Fin.',
#  'Aarti Industries',
#  'Abbott India',
#  'Action Const.Eq.',
#  'Adani Enterp.',
#  'Adani Ports',
#  'Adani Power',
#  'Adani Total Gas',
#  'Adani Wilmar',
#  'Aditya AMC',
#  'Aditya Birla Cap',
#  'Aether Industri.',
#  'Affle India',
#  'Ajanta Pharma',
#  'Akzo Nobel',
#  'Alembic Pharma',
#  'Alkem Lab',
#  'Altius Telecom',
#  'Amara Raja Ener.',
#  'Ambuja Cements',
#  'Ami Organics',
#  'Anand Rathi Wea.',
#  'Anant Raj',
#  'Angel One',
#  'Apar Inds.',
#  'Apollo Hospitals',
#  'Apollo Tyres',
#  'Asahi India Glas',
#  'Ashok Leyland',
#  'Astral',
#  'Atul',
#  'Aurobindo Pharma',
#  'Authum Invest',
#  'Avanti Feeds',
#  'Avenue Super.',
#  'Axis Bank',
#  'BSE',
#  'Bajaj Auto',
#  'Bajaj Finance',
#  'Bajaj Finserv',
#  'Bajaj Holdings',
#  'Bajaj Housing',
#  'Balkrishna Inds',
#  'Bandhan Bank',
#  'Bank of Baroda',
# ...
